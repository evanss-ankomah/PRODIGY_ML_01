# %% [markdown]
# Importing libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the training dataset

# %%
data = pd.read_csv('train.csv')

# %% [markdown]
# Selecting the relevant features; square footage, bedrooms and bathrooms.
# We then use GrivLivArea, Bedroom, FullBath as the independent variables(prediction)
# and then SalePrice as the dependemt variable(target)

# %%
features = ['GrLivArea', 'BedroomAbvGr', 'FullBath', 'HalfBath']
target = 'SalePrice'

# %% [markdown]
# Handling missing values if any

# %%
data = data.dropna(subset=features + [target])

# %% [markdown]
# Define the features (X) and the target variable (y)

# %%
x = data[features]
y = data[target]

# %% [markdown]
# Split the dataset into training and testing sets

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
#  Initializing the Linear Regression model

# %%
model = LinearRegression()

# %% [markdown]
# Train the model

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Making predictions on the test set

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# Evaluating the model

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 2810942965.218065
# R-squared: 0.6335301929422246

# %% [markdown]
# Visualizing the Predicted Prices and the Actual Prices

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted House Prices')
plt.show()
